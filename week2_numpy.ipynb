# %%
a=np.genfromtxt("winequality-red.csv", delimiter=",", skip_header=1)
a
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
b=a.astype(float)
b
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
c=np.shape(b)
c
# Out:
# (1599, 12)

# %%
print(b[2][3])
# Out:
# 2.3

# %%
b.shape
# Out:
# (1599, 12)

# %%
print(b[0:3,3])
# Out:
# [1.9 2.6 2.3]

# %%
b[0:3,3]
# Out:
# array([1.9, 2.6, 2.3])

# %%
print(b[:,2])
# Out:
# [0.   0.   0.04 ... 0.13 0.12 0.47]

# %%
print(b[3,:])
# Out:
# [11.2    0.28   0.56   1.9    0.075 17.    60.     0.998  3.16   0.58
#   9.8    6.   ]

# %%
b[1,5]
# Out:
# 25.0

# %%
b[1,5]=10.0
b
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
b[1,5]
# Out:
# 10.0

# %%
slice_new=b[:,9]
print(slice_new)
slice_new[:]=666
print(slice_new)
# Out:
# [0.56 0.68 0.65 ... 0.75 0.71 0.66]
# [666. 666. 666. ... 666. 666. 666.]

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.dtype
# Out:
# dtype('float64')

# %%
d=b.astype(int)
print(d)
# Out:
# [[  7   0   0 ... 666   9  15]
#  [  7   0   0 ... 666   9  15]
#  [  7   0   0 ... 666   9  15]
#  ...
#  [  6   0   0 ... 666  11  16]
#  [  5   0   0 ... 666  10  15]
#  [  6   0   0 ... 666  11  16]]

# %%
d.dtype
# Out:
# dtype('int32')

# %%
e=d[:,11]-10

# %%
e
# Out:
# array([5, 5, 5, ..., 6, 5, 6])

# %%
d
# Out:
# array([[  7,   0,   0, ..., 666,   9,  15],
#        [  7,   0,   0, ..., 666,   9,  15],
#        [  7,   0,   0, ..., 666,   9,  15],
#        ...,
#        [  6,   0,   0, ..., 666,  11,  16],
#        [  5,   0,   0, ..., 666,  10,  15],
#        [  6,   0,   0, ..., 666,  11,  16]])

# %%
e=d[:,11]-10
e
# Out:
# array([5, 5, 5, ..., 6, 5, 6])

# %%
d[:,11]=e
d
# Out:
# array([[  7,   0,   0, ..., 666,   9,   5],
#        [  7,   0,   0, ..., 666,   9,   5],
#        [  7,   0,   0, ..., 666,   9,   5],
#        ...,
#        [  6,   0,   0, ..., 666,  11,   6],
#        [  5,   0,   0, ..., 666,  10,   5],
#        [  6,   0,   0, ..., 666,  11,   6]])

# %%
e=d[:,11]+10
e
# Out:
# array([15, 15, 15, ..., 16, 15, 16])

# %%
d[:,11]=e
d
# Out:
# array([[  7,   0,   0, ..., 666,   9,  15],
#        [  7,   0,   0, ..., 666,   9,  15],
#        [  7,   0,   0, ..., 666,   9,  15],
#        ...,
#        [  6,   0,   0, ..., 666,  11,  16],
#        [  5,   0,   0, ..., 666,  10,  15],
#        [  6,   0,   0, ..., 666,  11,  16]])

# %%
s=np.sum(d)
s
# Out:
# 1226388

# %%
sc=np.sum(d,axis=0)
sc
# Out:
# array([  12589,      24,       1,    3350,       0,   25367,   74301,
#             81,    4770, 1064934,   15969,   25002])

# %%
sr=np.sum(d,axis=1)
sr
# Out:
# array([746, 779, 771, ..., 773, 777, 765])

# %%
f=[i+i for i in d[:,11]]
print(f)
# Out:
# [30, 30, 30, 32, 30, 30, 30, 34, 34, 30, 30, 30, 30, 30, 30, 30, 34, 30, 28, 32, 32, 30, 30, 30, 32, 30, 30, 30, 30, 32, 30, 32, 30, 32, 30, 32, 32, 34, 28, 30, 30, 28, 32, 30, 30, 28, 30, 30, 30, 30, 30, 32, 32, 30, 32, 30, 30, 30, 30, 32, 30, 30, 34, 30, 30, 30, 30, 30, 30, 32, 32, 30, 30, 28, 30, 30, 30, 32, 30, 28, 30, 30, 30, 30, 32, 30, 32, 30, 30, 30, 30, 32, 30, 30, 28, 32, 30, 30, 30, 32, 32, 32, 32, 30, 30, 30, 30, 30, 32, 30, 30, 30, 30, 32, 30, 32, 32, 32, 32, 32, 30, 32, 30, 30, 30, 30, 30, 30, 34, 30, 30, 30, 30, 32, 32, 30, 30, 30, 30, 30, 30, 30, 32, 30, 32, 30, 30, 30, 32, 32, 32, 28, 30, 30, 30, 30, 30, 30, 30, 32, 30, 28, 32, 30, 30, 30, 30, 28, 32, 30, 28, 32, 32, 32, 30, 30, 30, 32, 30, 30, 30, 30, 30, 30, 32, 30, 30, 30, 30, 30, 30, 32, 30, 30, 30, 30, 30, 32, 34, 28, 34, 30, 30, 30, 32, 34, 34, 30, 30, 34, 32, 32, 32, 30, 32, 30, 30, 30, 30, 30, 32, 30, 30, 32, 28, 32, 32, 30, 32, 30, 34, 32, 32, 30, 32, 32, 32, 32, 32, 32, 30, 32, 32, 34, 34, 32, 30, 30, 32, 3
# ...

# %%
d[:,11]=f
print(d)
# Out:
# [[  7   0   0 ... 666   9  30]
#  [  7   0   0 ... 666   9  30]
#  [  7   0   0 ... 666   9  30]
#  ...
#  [  6   0   0 ... 666  11  32]
#  [  5   0   0 ... 666  10  30]
#  [  6   0   0 ... 666  11  32]]

# %%
d[:,10]%=d[:,11]
d
# Out:
# array([[   7,    0,    0, ...,  666,    0,  900],
#        [   7,    0,    0, ...,  666,    0,  900],
#        [   7,    0,    0, ...,  666,    0,  900],
#        ...,
#        [   6,    0,    0, ...,  666,    0, 1024],
#        [   5,    0,    0, ...,  666,    0,  900],
#        [   6,    0,    0, ...,  666,    0, 1024]])

# %%
k=b[:,11]-10
b[:,11]=k

# %%
for i in b[:,11]:
    if(i>5):
        print(i)
# Out:
# 6.0
# 7.0
# 7.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 7.0
# 6.0
# 7.0
# 7.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 7.0
# 8.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 8.0
# 7.0
# 6.0
# 7.0
# 7.0
# 6.0
# 6.0
# 7.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 7.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 7.0
# 6.0
# 6.0
# 7.0
# 6.0
# 7.0
# 7.0
# 6.0
# 6.0
# 6.0
# 7.0
# 6.0
# 7.0
# ...

# %%
c=0
for i in b[:,11]:
    if(i==10):
        c+=1
if(c!=0):
    print("Wines has Quality 10")
else:
    print("No wines has Quality 10")
# Out:
# No wines has Quality 10
